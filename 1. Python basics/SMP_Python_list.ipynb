# %%
# datatypes - int, str, float, bool , operators, mebership fun's

# Lists , Tuple, Sets, Dictionaries

# Lists -   []

names = ['lovely','parth','rohit','ganesh','kalkidan', 10.4, True, 52 , -521]
print(type(names))
# Out:
# <class 'list'>

# %%
# Indexes always start from zero - when LEFT --> RIGHT
print(names[-1], names[1] , names[8], names[-2])  # printing only one value by giving the index
# Out:
# -521 parth -521 52

# %%
# Slicing the index

# list_name[Lower bound : Upper Bound-1]  --> Lower Bound are Inclusive and Upper bOund are Exclusive

print(names[1:6],  names[-8:-3], names[1:-3])
print(names[1:3])
# Out:
# ['parth', 'rohit', 'ganesh', 'kalkidan', 10.4] ['parth', 'rohit', 'ganesh', 'kalkidan', 10.4] ['parth', 'rohit', 'ganesh', 'kalkidan', 10.4]
# ['parth', 'rohit']

# %%
# List concatination

new_list = names[0:5] + names[7:9] + ['new' , 'values']  +['not a list']

print(new_list)
# Out:
# ['lovely', 'parth', 'rohit', 'ganesh', 'kalkidan', 52, -521, 'new', 'values', 'not a list']

# %%
a=[1,3,4,5,6,7]

a[2:] # start from index 2 till the very end

a[:4] # index 4 exclusive , will give evertything b4 index 4

a[:-2] # index -2 exclusive , will give evertything b4 index -2

a[-3: ] # Everthing after index -3 till last

a[ : 4] # everting b4 index 4 - and 4 is upper bound so Excluded
# Out:
# [1, 3, 4, 5]

# %%
# names[1:3]
names[1]+' '+ names[3]
# Out:
# 'parth ganesh'

# %%
new_list= ['lovely', 'parth', 'rohit', 'ganesh', 'kalkidan', 5.2, -521, 'new', 'values', 'not a list']

# overwrite an existing value in a list
new_list[5] = 5000
new_list
# Out:
# ['lovely',
#  'parth',
#  'rohit',
#  'ganesh',
#  'kalkidan',
#  5000,
#  -521,
#  'new',
#  'values',
#  'not a list']

# %%
new_list[1:3] = 'abc' ,'pqr'  # 1,2
new_list
# Out:
# ['lovely',
#  'abc',
#  'pqr',
#  'ganesh',
#  'kalkidan',
#  5000,
#  -521,
#  'new',
#  'values',
#  'not a list']

# %%
list2 = new_list + ['lovely', 'parth', 'rohit', 'ganesh', 'kalkidan']
print(list2)
# Out:
# ['lovely', 'abc', 'pqr', 'ganesh', 'kalkidan', 5000, -521, 'new', 'values', 'not a list', 'lovely', 'parth', 'rohit', 'ganesh', 'kalkidan']

# %%
# list_name.index(values)
list2.index(5000) # but if values are repated then- it will return the very first index
# Out:
# 5

# %%
# remove ,insert 
new_list
# Out:
# ['lovely',
#  'abc',
#  'pqr',
#  'ganesh',
#  'kalkidan',
#  5000,
#  -521,
#  'new',
#  'values',
#  'not a list']

# %%
new_list.insert(0, 'Canisha') # (index, new_value)

# %%
new_list.remove('not a list') # (value to be removed)

# %%
# list2.remove('lovely')
list2
# Out:
# ['lovely',
#  'abc',
#  'pqr',
#  'ganesh',
#  'kalkidan',
#  5000,
#  -521,
#  'new',
#  'values',
#  'not a list',
#  'lovely',
#  'parth',
#  'rohit',
#  'ganesh',
#  'kalkidan']

# %%
l1=['lovely', 'parth', 'rohit', 'ganesh', 'kalkidan']
l1.pop(2)
l1.remove('parth')
print(l1)
# Out:
# ['lovely', 'rohit', 'ganesh', 'kalkidan']

# %%
# pop function will remove values given index
new_list.pop(3)  
new_list
# Out:
# ['Canisha', 'lovely', 'abc', 'ganesh', 'kalkidan', 5000, -521, 'new', 'values']

# %%
len(new_list)-1  # length will return total count of elemnets
# Out:
# 8

# %%
new_list.pop(len(new_list)-1)
# Out:
# 'values'

# %%
# new_list[-1]='dileep'
new_list.remove(5000)
new_list.remove(-521)
new_list
# Out:
# ['Canisha', 'lovely', 'abc', 'ganesh', 'kalkidan', 'dileep']

# %%
# list are MUTABLE -- i can make changes to them

# %%
# FOR LOOPS
for v in new_list:
    new_name1 ='Hello '+ v   

print(new_name1)
# Out:
# Hello dileep

# %%
l1=['lovely', 'rohit', 'ganesh', 'kalkidan','lovely','lovely']
l1.extend(['lovely'])

for ind,val in enumerate(l1):
  print(ind, val)
# Out:
# 0 lovely
# 1 rohit
# 2 ganesh
# 3 kalkidan
# 4 lovely
# 5 lovely
# 6 lovely

# %%
# reverse

# l1=list(reversed(l1))
# for i,j in enumerate(l1):
#   print(i,j)

# for i,j in enumerate(l1[::-1]):
#   print(i,j)
print(l1)
# Out:
# ['lovely', 'lovely', 'lovely', 'kalkidan', 'ganesh', 'rohit', 'lovely']

# %%
l1[0:7:3]  # listname[start index: end index: step size=1]  - upper bound is excluded
# Out:
# ['lovely', 'kalkidan', 'lovely']

# %%
# l1[::-1]

# %%
l1[:-1] # start from end
# Out:
# ['lovely', 'lovely', 'lovely', 'kalkidan', 'ganesh', 'rohit']

# %%
l1[2:] # start everthibg after index 2
# Out:
# ['lovely', 'kalkidan', 'ganesh', 'rohit', 'lovely']

# %%
#  independent function - returns (index and value)
for a,k in enumerate('helloh'):
    print('Index is ', a, 'Value is', k)
# Out:
# Index is  0 Value is h
# Index is  1 Value is e
# Index is  2 Value is l
# Index is  3 Value is l
# Index is  4 Value is o
# Index is  5 Value is h

# %%
#  independent function - returns index and value
for ind,val in enumerate(list2):
    print('Index is ', ind, 'Value is', val)
# Out:
# Index is  0 Value is lovely
# Index is  1 Value is abc
# Index is  2 Value is pqr
# Index is  3 Value is ganesh
# Index is  4 Value is kalkidan
# Index is  5 Value is 5000
# Index is  6 Value is -521
# Index is  7 Value is new
# Index is  8 Value is values
# Index is  9 Value is not a list
# Index is  10 Value is lovely
# Index is  11 Value is parth
# Index is  12 Value is rohit
# Index is  13 Value is ganesh
# Index is  14 Value is kalkidan

# %%
list2 = [10, 20.6, 'hello' , False] 
for v in list2:
    print(type(v))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# APPEND - allow to add new values one by one to Existing/ new list
# adding to existing list

# %%
new_list=['Canisha', 'lovely', 'parth', 'rohit', 'ganesh']
new_names = ['Bharat', 'swati', 'Woo']
lis_num = [20,21,22]

for i in lis_num:
    new_list.append(i+1000)

print(new_list)
# Out:
# ['Canisha', 'lovely', 'parth', 'rohit', 'ganesh', 1020, 1021, 1022]

# %%
new_list=['Canisha', 'lovely', 'parth', 'rohit', 'ganesh', 'Cia']
l2 = []
for i in new_list:
    l2.append(i[0])
print(l2)
# Out:
# ['C', 'l', 'p', 'r', 'g', 'C']

# %%
# if - else  - allow to check conditions

for i in new_list:
    if i[0] == 'C':
        print(i)
    else:
        print('name do not start with C')
# Out:
# Canisha
# name do not start with C
# name do not start with C
# name do not start with C
# name do not start with C
# Cia

# %%
for i in new_list:
    if i[0]=='C':
        print(i)
    else:
        print('name does not start with C')

# %%
nl = ['a','b','c','a','b']
for ind, val in enumerate(nl, 100):   # index , value from list
    print(ind,val)
# Out:
# 0 a
# 1 b
# 2 c
# 3 a
# 4 b

# %%
# SETS  - {} , does not allows duplicates  - un-ordered
s1 ={1,1,1000,1,1,1,20,2,2,2,3,4,4,56,6,7,7,8}
print(s1)
# Out:
# {1, 2, 3, 4, 6, 7, 1000, 8, 20, 56}

# %%
l1_set = set(l1)
print(l1_set)
# Out:
# {'kalkidan', 'rohit', 'ganesh', 'lovely'}

# %%
list(l1_set)
# Out:
# ['kalkidan', 'rohit', 'ganesh', 'lovely']

# %%
# add - only add 1 value at a time
l1_set.add('Kabindra')  # only accept 1 value
print(l1_set)
# Out:
# {'ganesh', 'Kabindra', 'lovely', 'kalkidan', 'rohit'}

# %%
# update  -- {}  - aloows to add multiple values to a existing set
l1_set.update(['juxiang','fuzailkhan','SHUBHAM','shubham'])
print(l1_set)
# Out:
# {'juxiang', 'ganesh', 'SHUBHAM', 'fuzailkhan', 'Kabindra', 'lovely', 'shubham', 'kalkidan', 'rohit'}

# %%
s2=set()
for val in l1_set:
  s2.add(val.swapcase())   #lower(), upper(), capitalize(), swapcase()

print(s2)
l1.count('lovely')  # count occurace of a value in list
# Out:
# {'FUZAILKHAN', 'kABINDRA', 'SHUBHAM', 'GANESH', 'LOVELY', 'shubham', 'ROHIT', 'JUXIANG', 'KALKIDAN'}
# 4

# %%
s2.remove('Lovely')
print(s2)
# Out:
# {'Shubham', 'Kabindra', 'Rohit', 'Juxiang', 'Fuzailkhan', 'Ganesh', 'Kalkidan'}
