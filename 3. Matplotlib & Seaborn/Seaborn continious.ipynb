# %%
# Categorical Data Plots
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# sns.get_dataset_names()

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# from Matplotlib
# https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html
#
# from Seaborn
# https://seaborn.pydata.org/generated/seaborn.set_style.html

# %%
sns.lmplot(x="total_bill",
           y="tip",
           row="sex",
           col="time",
           hue = 'smoker',
           data=tips)

# %%
sns.distplot(tips['tip'], kde = False) # Kernal Density estimation

# single feature analysis - Univariet Analysis
# dual feature analysis - Bivariet Analysis
# multiple feature analysis - Multivariet Analysis
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter');

# %%
sns.pairplot(tips, hue = 'sex') # multivariet

# %%
sns.kdeplot(tips['total_bill']) # Kernel density estimation graph
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.rugplot(tips['tip'])
# Out:
# <AxesSubplot:xlabel='tip'>
